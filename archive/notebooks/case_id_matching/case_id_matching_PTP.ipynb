# %%
# Check out additional features for extraction

# %%
import ast

import pandas as pd

# %load_ext autoreload

# %%
pd.set_option('display.max_colwidth', None)

# %%
df_features = pd.read_csv('../../data_v3/ptp_il_tagged.csv')
df_test = pd.read_csv('../../data_v3/ptp_emitted_events_test.csv')

# %%
df_gt = pd.read_csv("../../data_v3/ptp_ground_truth.csv")

# %%
# HR data in data/Train/R1 is missing frame.number. We take another (already filtered) dataset and apply our feature extraction to this one
df_train_in = pd.read_csv('../../data/VALID/R1/R1.csv', converters={"MessageAttributes": ast.literal_eval})
# This is the Interleaved Data Set for our pipeline
df_il_in = pd.read_csv('../../data/PTP-INTERLEAVED/R1/R1.csv', converters={"MessageAttributes": ast.literal_eval})

# %%
from event_loop.preprocessing.dataframe import pre_process

df_train_pp = pre_process(df_train_in)
df_il_pp = pre_process(df_il_in)

# %%
def mark_start_end(df):
    # Mark start event of each BusinessActivity Instance
    df["activityStart"] = df.groupby(["BusinessActivity", "InstanceNumber", ]).cumcount() == 0
    # Mark end event of each Business Activity Instance
    df["activityEnd"] = df.groupby(["BusinessActivity", "InstanceNumber", ]).cumcount(ascending=False) == 0
    # Merge start and end columns to form labels
    df["ActivityAction"] = df.apply(lambda row: "Activity Start" if row["activityStart"] else (
        "Activity End" if row["activityEnd"] else 'NoAction'), axis=1)

    return df.drop(["activityStart", 'activityEnd'], axis=1)

df_train_pp = mark_start_end(df_train_pp)

# %%
df_train_pp["pgsql.query_0"] = df_train_pp["pgsql.query"].str.split(" ").str[0]
df_il_pp["pgsql.query_0"]= df_il_pp["pgsql.query"].str.split(" ").str[0]

# %%
from event_loop.preprocessing.event_attributes import *

# %autoreload 2


df_train_pp["sale_order_id"] = df_train_pp.apply(lambda x: extract_sale_order_id(x["pgsql.query"], x["pgsql.query_0"], x["pgsql.target"], x["file_data"], x["selective_file_data"], x["origin_file_data"]), axis=1)
df_train_pp["sale_order_line_id"] = df_train_pp.apply(lambda x: extract_sale_order_line_id(x["pgsql.query"], x["pgsql.query_0"], x["pgsql.target"], x["file_data"], x["selective_file_data"], x["origin_file_data"]), axis=1)
df_train_pp["purchase_requisition_id"] = df_train_pp.apply(lambda x: extract_purchase_requisition_id(x["pgsql.query"], x["pgsql.query_0"], x["pgsql.target"], x["file_data"], x["selective_file_data"], x["origin_file_data"]), axis=1)
df_train_pp["purchase_requisition_line_id"] = df_train_pp.apply(lambda x: extract_purchase_requisition_line_id(x["pgsql.query"], x["pgsql.query_0"], x["pgsql.target"], x["file_data"], x["selective_file_data"], x["origin_file_data"]), axis=1)
df_train_pp["purchase_order_id"] = df_train_pp.apply(lambda x: extract_purchase_order_id(x["pgsql.query"], x["pgsql.query_0"], x["pgsql.target"], x["file_data"], x["selective_file_data"], x["origin_file_data"]), axis=1)
df_train_pp["purchase_order_line_id"] = df_train_pp.apply(lambda x: extract_purchase_order_line_id(x["pgsql.query"], x["pgsql.query_0"], x["pgsql.target"], x["file_data"], x["selective_file_data"], x["origin_file_data"]), axis=1)

# %%
df_train_pp["file_data_str"] = df_train_pp["file_data"].apply(lambda x: ", ".join(x))

# %%
q = "58"

#cond1 = df_train_pp[['sale_order_id', 'sale_order_line_id']].isnull().all(axis=1) 
cond2 = (df_train_pp["file_data_str"].str.contains(q))| (df_train_pp["pgsql.query"].str.contains(q))
cond3 = df_train_pp["InstanceNumber"] == 1
cond4 = df_train_pp["BusinessActivity"] == "ReceiveGoods"

df_train_pp[cond3 & cond4][["InstanceNumber","pgsql.query","file_data","origin_file_data","pgsql.target","sale_order_id","sale_order_line_id","purchase_requisition_id","purchase_requisition_line_id"]]
# Out:
#          InstanceNumber  \
# 2797505               1
# 2797560               1
# 2797564               1
# 2797666               1
# 2797736               1
# 2797740               1
# 2797945               1
# 2797949               1
# 2798250               1
# 2798254               1
# 2798383               1
# 2798387               1
# 2798504               1
# 2798525               1
# 2798529               1
# 2798975               1
# 2799082               1
# 2799120               1
# 2799128               1
# 2799240               1
# 2799300               1
# 2799555               1
# 2799624               1
# 2799675               1
# 2799684               1
# 2799825               1
# 2799882               1
# 2799935               1
# 2800253               1
# 2800291               1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             pgsql.query  \
# 2797505
# 2797560
# 2797564
# 2797666                                                                                                                                                                                                                                                                                                                                                                                                                                                                  INSERT INTO "res_users_log" ("id", "create_uid", "create_date", "write_uid", "write_date") VALUES (nextval('res_users_log_id_seq'), 2, (now() at time zone 'UTC'), 2, (now() at time zone 'UTC')) RETURNING id
# 2797736
# 2797740
# 2797945
# 2797949
# 2798250
# 2798254
# 2798383
# 2798387
# 2798504                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          UPDATE "stock_move_line" SET "qty_done"='1.000',"write_uid"=2,"write_date"=(now() at time zone 'UTC') WHERE id IN (56)
# 2798525
# 2798529
# 2798975                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                UPDATE "stock_quant" SET "quantity"= -4.0,"in_date"='2020-12-17 08:00:13',"write_uid"=1,"write_date"=(now() at time zone 'UTC') WHERE id IN (46)
# 2799082                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  UPDATE "stock_quant" SET "quantity"=4.0,"in_date"='2020-12-17 08:00:13',"write_uid"=1,"write_date"=(now() at time zone 'UTC') WHERE id IN (47)
# 2799120                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      UPDATE "stock_move_line" SET "product_uom_qty"='0.000',"date"='2020-12-21 06:20:20',"write_uid"=2,"write_date"=(now() at time zone 'UTC') WHERE id IN (56)
# 2799128                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           UPDATE "stock_move_line" SET "product_qty"=0.0,"write_uid"=2,"write_date"=(now() at time zone 'UTC') WHERE id IN (56)
# 2799240                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      UPDATE "stock_move" SET "state"='done',"date"='2020-12-21 06:20:20',"write_uid"=2,"write_date"=(now() at time zone 'UTC') WHERE id IN (65)
# 2799300                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              UPDATE "stock_move_line" SET "state"='done',"write_uid"=2,"write_date"=(now() at time zone 'UTC') WHERE id IN (56)
# 2799555                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           UPDATE "purchase_order" SET "picking_count"=1,"write_uid"=2,"write_date"=(now() at time zone 'UTC') WHERE id IN (152)
# 2799624                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                UPDATE "stock_picking" SET "state"='done',"write_uid"=2,"write_date"=(now() at time zone 'UTC') WHERE id IN (55)
# 2799675  INSERT INTO "mail_message" ("id", "create_uid", "create_date", "write_uid", "write_date", "add_sign", "author_id", "body", "date", "email_from", "message_id", "message_type", "model", "no_auto_thread", "record_name", "reply_to", "res_id", "subject", "subtype_id") VALUES (nextval('mail_message_id_seq'), 1, (now() at time zone 'UTC'), 1, (now() at time zone 'UTC'), true, 3, '', '2020-12-21 06:20:20', 'Mitchell Admin <admin@yourcompany.example.com>', '<139160290806087.1608531620.573164463043213-openerp-message-notify@BPW10OD01>', 'notification', 'stock.picking', false, NULL, 'Mitchell Admin <admin@yourcompany.example.com>', 55, NULL, 2) RETURNING id
# 2799684                                                                                                                                                                                                                                                                           INSERT INTO "mail_tracking_value" ("id", "create_uid", "create_date", "write_uid", "write_date", "field", "field_desc", "field_type", "mail_message_id", "new_value_char", "old_value_char", "track_sequence") VALUES (nextval('mail_tracking_value_id_seq'), 1, (now() at time zone 'UTC'), 1, (now() at time zone 'UTC'), 'state', 'Status', 'selection', 10017, 'Done', 'Ready', 100) RETURNING id
# 2799825                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           UPDATE "stock_move" SET "price_unit"=0.0,"value"=0.0,"remaining_value"=5.0,"remaining_qty"=1.0,"write_uid"=2,"write_date"=(now() at time zone 'UTC') WHERE id IN (65)
# 2799882                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 UPDATE "purchase_order_line" SET "qty_received"='1.000',"write_uid"=1,"write_date"=(now() at time zone 'UTC') WHERE id IN (163)
# 2799935                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               UPDATE "purchase_order" SET "invoice_status"='to invoice',"write_uid"=1,"write_date"=(now() at time zone 'UTC') WHERE id IN (152)
# 2800253                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             UPDATE "stock_picking" SET "date_done"='2020-12-21 06:20:20',"write_uid"=2,"write_date"=(now() at time zone 'UTC') WHERE id IN (55)
# 2800291
#
#                                                                                                                  file_data  \
# 2797505                                                                                                                 []
# 2797560  [server_version, 12.0-20190820, server_version_info, 12, 0, 0, final, 0, server_serie, 12.0, protocol_version, 1]
# 2797564                                                                       [odoo01, user.suername@company.com, PWD1234]
# 2797666
# 2797736                                                                                                                [2]
# 2797740                       [odoo01, 2, PWD1234, purchase.order, search_read, id, =, 152, fields, picking_ids, limit, 1]
# 2797945                                                                                         [id, 152, picking_ids, 55]
# 2797949            [odoo01, 2, PWD1234, stock.picking, search_read, id, =, 55, fields, move_ids_without_package, limit, 1]
# 2798250                                                                             [id, 55, move_ids_without_package, 65]
# 2798254                          [odoo01, 2, PWD1234, stock.move, search_read, id, =, 65, fields, move_line_ids, limit, 1]
# 2798383                                                                                        [id, 65, move_line_ids, 56]
# 2798387                                                      [odoo01, 2, PWD1234, stock.move.line, write, 56, qty_done, 1]
# 2798504
# 2798525                                                                                                                [1]
# 2798529                                                           [odoo01, 2, PWD1234, stock.picking, button_validate, 55]
# 2798975
# 2799082
# 2799120
# 2799128
# 2799240
# 2799300
# 2799555
# 2799624
# 2799675
# 2799684
# 2799825
# 2799882
# 2799935
# 2800253
# 2800291                                                                                                                 []
#
#                       origin_file_data         pgsql.target sale_order_id  \
# 2797505                                                              None
# 2797560                        version                               None
# 2797564                                                              None
# 2797666                                       res_users_log          None
# 2797736                                                              None
# 2797740                                                              None
# 2797945     purchase.order_search_read                               None
# 2797949                                                              None
# 2798250      stock.picking_search_read                               None
# 2798254                                                              None
# 2798383         stock.move_search_read                               None
# 2798387                                                              None
# 2798504                                     stock_move_line          None
# 2798525          stock.move.line_write                               None
# 2798529                                                              None
# 2798975                                         stock_quant          None
# 2799082                                         stock_quant          None
# 2799120                                     stock_move_line          None
# 2799128                                     stock_move_line          None
# 2799240                                          stock_move          None
# 2799300                                     stock_move_line          None
# 2799555                                      purchase_order          None
# 2799624                                       stock_picking          None
# 2799675                                        mail_message          None
# 2799684                                 mail_tracking_value          None
# 2799825                                          stock_move          None
# 2799882                                 purchase_order_line          None
# 2799935                                      purchase_order          None
# 2800253                                       stock_picking          None
# 2800291  stock.picking_button_validate                               None
#
#         sale_order_line_id purchase_requisition_id  \
# 2797505               None                    None
# 2797560               None                    None
# 2797564               None                    None
# 2797666               None                    None
# 2797736               None                    None
# 2797740               None                    None
# 2797945               None                    None
# 2797949               None                    None
# 2798250               None                    None
# 2798254               None                    None
# 2798383               None                    None
# 2798387               None                    None
# 2798504               None                    None
# 2798525               None                    None
# 2798529               None                    None
# 2798975               None                    None
# 2799082               None                    None
# 2799120               None                    None
# 2799128               None                    None
# 2799240               None                    None
# 2799300               None                    None
# 2799555               None                    None
# 2799624               None                    None
# 2799675               None                    None
# 2799684               None                    None
# 2799825               None                    None
# 2799882               None                    None
# 2799935               None                    None
# 2800253               None                    None
# 2800291               None                    None
#
#         purchase_requisition_line_id
# 2797505                         None
# 2797560                         None
# 2797564                         None
# 2797666                         None
# 2797736                         None
# 2797740                         None
# 2797945                         None
# 2797949                         None
# 2798250                         None
# 2798254                         None
# 2798383                         None
# 2798387                         None
# 2798504                         None
# 2798525                         None
# 2798529                         None
# 2798975                         None
# 2799082                         None
# 2799120                         None
# 2799128                         None
# 2799240                         None
# 2799300                         None
# 2799555                         None
# 2799624                         None
# 2799675                         None
# 2799684                         None
# 2799825                         None
# 2799882                         None
# 2799935                         None
# 2800253                         None
# 2800291                         None

# %%
unique_no_nan = lambda x: list(filter(None, pd.unique(x)))

df_train_pp.groupby(["InstanceNumber"]).agg(
    {"sale_order_id": unique_no_nan, "sale_order_line_id": unique_no_nan, "purchase_requisition_id": unique_no_nan,
     "purchase_requisition_line_id": unique_no_nan, "purchase_order_id": unique_no_nan,
     'purchase_order_line_id': unique_no_nan})
# Out:
#                sale_order_id sale_order_line_id purchase_requisition_id  \
# InstanceNumber
# 1                       [94]              [118]                    [58]
# 2                       [95]              [119]                    [59]
# 3                       [96]              [120]                    [60]
# 4                       [97]              [121]                    [61]
# 5                       [98]              [122]                    [62]
# ...                      ...                ...                     ...
# 63                     [156]              [180]                   [120]
# 64                     [157]              [181]                   [121]
# 65                     [158]              [182]                   [122]
# 66                     [159]              [183]                   [123]
# 67                     [160]              [184]                   [124]
#
#                purchase_requisition_line_id  \
# InstanceNumber
# 1                                      [58]
# 2                                      [59]
# 3                                      [60]
# 4                                      [61]
# 5                                      [62]
# ...                                     ...
# 63                                    [120]
# 64                                    [121]
# 65                                    [122]
# 66                                    [123]
# 67                                    [124]
#
#                                                       purchase_order_id  \
# InstanceNumber
# 1                              [152, 152, 153, 153, 154, 154, 153, 154]
# 2                                                  [155, 155, 156, 156]
# 3                                                  [157, 157, 158, 158]
# 4                                                  [159, 159, 160, 160]
# 5                              [161, 161, 162, 162, 163, 163, 161, 162]
# ...                                                                 ...
# 63                                                 [346, 346, 347, 347]
# 64              [348, 348, 349, 349, 350, 350, 351, 351, 349, 350, 351]
# 65                                       [352, 352, 353, 353, 354, 354]
# 66                             [355, 355, 356, 356, 357, 357, 358, 358]
# 67                                                 [359, 359, 360, 360]
#
#                              purchase_order_line_id
# InstanceNumber
# 1                         [163, 164, 165, 164, 165]
# 2                                        [166, 167]
# 3                                        [168, 169]
# 4                                        [170, 171]
# 5                         [172, 173, 174, 172, 173]
# ...                                             ...
# 63                                       [357, 358]
# 64              [359, 360, 361, 362, 360, 361, 362]
# 65                                  [363, 364, 365]
# 66                             [366, 367, 368, 369]
# 67                                       [370, 371]
#
# [67 rows x 6 columns]

# %%
unique_no_nan = lambda x: list(filter(None, pd.unique(x)))

df_train_pp.groupby(["InstanceNumber","BusinessActivity"]).agg(
    {"sale_order_id": unique_no_nan, "sale_order_line_id": unique_no_nan, "purchase_requisition_id": unique_no_nan,
     "purchase_requisition_line_id": unique_no_nan, "purchase_order_id": unique_no_nan,
     'purchase_order_line_id': unique_no_nan})
# Out:
#                                      sale_order_id sale_order_line_id  \
# InstanceNumber BusinessActivity
# 1              BidSelection                     []                 []
#                CreateCallForTender            [94]                 []
#                CreatePurchaseOrder            [94]              [118]
#                CreatePurchaseRequest          [94]              [118]
#                CreateRfq                      [94]                 []
# ...                                            ...                ...
# 67             CreatePurchaseOrder           [160]              [184]
#                CreatePurchaseRequest         [160]              [184]
#                CreateRfq                     [160]                 []
#                ReceiveGoods                     []                 []
#                SubmitPayment                 [160]                 []
#
#                                      purchase_requisition_id  \
# InstanceNumber BusinessActivity
# 1              BidSelection                             [58]
#                CreateCallForTender                      [58]
#                CreatePurchaseOrder                      [58]
#                CreatePurchaseRequest                      []
#                CreateRfq                                [58]
# ...                                                      ...
# 67             CreatePurchaseOrder                     [124]
#                CreatePurchaseRequest                      []
#                CreateRfq                               [124]
#                ReceiveGoods                               []
#                SubmitPayment                              []
#
#                                      purchase_requisition_line_id  \
# InstanceNumber BusinessActivity
# 1              BidSelection                                    []
#                CreateCallForTender                           [58]
#                CreatePurchaseOrder                             []
#                CreatePurchaseRequest                           []
#                CreateRfq                                       []
# ...                                                           ...
# 67             CreatePurchaseOrder                             []
#                CreatePurchaseRequest                           []
#                CreateRfq                                       []
#                ReceiveGoods                                    []
#                SubmitPayment                                   []
#
#                                                    purchase_order_id  \
# InstanceNumber BusinessActivity
# 1              BidSelection                                       []
#                CreateCallForTender                                []
#                CreatePurchaseOrder    [152, 152, 153, 154, 154, 153]
#                CreatePurchaseRequest                              []
#                CreateRfq              [152, 152, 153, 153, 154, 154]
# ...                                                              ...
# 67             CreatePurchaseOrder                   [360, 360, 359]
#                CreatePurchaseRequest                              []
#                CreateRfq                        [359, 359, 360, 360]
#                ReceiveGoods                                    [360]
#                SubmitPayment                                   [360]
#
#                                          purchase_order_line_id
# InstanceNumber BusinessActivity
# 1              BidSelection                                  []
#                CreateCallForTender                           []
#                CreatePurchaseOrder    [163, 165, 164, 164, 165]
#                CreatePurchaseRequest                         []
#                CreateRfq                        [163, 164, 165]
# ...                                                         ...
# 67             CreatePurchaseOrder                   [371, 370]
#                CreatePurchaseRequest                         []
#                CreateRfq                             [370, 371]
#                ReceiveGoods                               [371]
#                SubmitPayment                              [371]
#
# [409 rows x 6 columns]

# %%
unique_no_nan = lambda x: list(filter(None, pd.unique(x)))

df_il_pp.groupby(["InstanceNumber", "BusinessActivity"]).agg(
    {"sale_order_id": unique_no_nan, "sale_order_line_id": unique_no_nan, "purchase_requisition_id": unique_no_nan,
     "purchase_requisition_line_id": unique_no_nan, "purchase_order_id": unique_no_nan,
     'purchase_order_line_id': unique_no_nan})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 3
#       1 unique_no_nan = lambda x: list(filter(None, pd.unique(x)))
# ----> 3 df_il_pp.groupby(["InstanceNumber", "BusinessActivity"]).agg(
#       4     {"sale_order_id": unique_no_nan, "sale_order_line_id": unique_no_nan, "purchase_requisition_id": unique_no_nan,
#       5      "purchase_requisition_line_id": unique_no_nan, "purchase_order_id": unique_no_nan,
#       6      'purchase_order_line_id': unique_no_nan})
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/pandas/core/groupby/generic.py:1442, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1439     kwargs["engine_kwargs"] = engine_kwargs
#    1441 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1442 result = op.agg()
#    1443 if not is_dict_like(func) and result is not None:
#    1444     # GH #52849
#    1445     if not self.as_index and is_list_like(func):
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/pandas/core/apply.py:175, in Apply.agg(self)
#     172     return self.apply_str()
#     174 if is_dict_like(func):
# --> 175     return self.agg_dict_like()
#     176 elif is_list_like(func):
#     177     # we require a list, but not a 'str'
#     178     return self.agg_list_like()
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/pandas/core/apply.py:406, in Apply.agg_dict_like(self)
#     398 def agg_dict_like(self) -> DataFrame | Series:
#     399     """
#     400     Compute aggregation in the case of a dict-like argument.
#     401
#    (...)
#     404     Result of aggregation.
#     405     """
# --> 406     return self.agg_or_apply_dict_like(op_name="agg")
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/pandas/core/apply.py:1388, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1383     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1385 with com.temp_setattr(
#    1386     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1387 ):
# -> 1388     result_index, result_data = self.compute_dict_like(
#    1389         op_name, selected_obj, selection, kwargs
#    1390     )
#    1391 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1392 return result
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/pandas/core/apply.py:445, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     443 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     444 func = cast(AggFuncTypeDict, self.func)
# --> 445 func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     447 is_non_unique_col = (
#     448     selected_obj.ndim == 2
#     449     and selected_obj.columns.nunique() < len(selected_obj.columns)
#     450 )
#     452 if selected_obj.ndim == 1:
#     453     # key only used for output
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/pandas/core/apply.py:639, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     637     cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     638     if len(cols) > 0:
# --> 639         raise KeyError(f"Column(s) {list(cols)} do not exist")
#     641 aggregator_types = (list, tuple, dict)
#     643 # if we have a dict of any non-scalars
#     644 # eg. {'A' : ['mean']}, normalize all to
#     645 # be list-likes
#     646 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['purchase_order_id', 'purchase_order_line_id', 'purchase_requisition_id', 'purchase_requisition_line_id', 'sale_order_id', 'sale_order_line_id'] do not exist"

# %%
df_gt
# Out:
#             activity_name   start     end  actual_end overlapping_activities  \
# 0   CreatePurchaseRequest      96    1367        1322                     []
# 1     CreateCallForTender    1367    1940        1887                     []
# 2   CreatePurchaseRequest    1940    2818        2793                     []
# 3               CreateRfq    2818    6289       15871                     []
# 4     CreateCallForTender    5563    6178        5965                     []
# ..                    ...     ...     ...         ...                    ...
# 58          SubmitPayment  100724  104625      104454                     []
# 59    CreatePurchaseOrder  101210  105998      105925                     []
# 60          SubmitPayment  106266  108727      108703                     []
# 61           ReceiveGoods  108727  109758      109696                     []
# 62          SubmitPayment  109758  112188      112188                     []
#
#     bp_id overlapping_bps  classification  Multi Class Classification  \
# 0     399              []             NaN                         NaN
# 1     399              []             NaN                         NaN
# 2     400              []             NaN                         NaN
# 3     399              []             NaN                         NaN
# 4     400              []             NaN                         NaN
# ..    ...             ...             ...                         ...
# 58    406              []             NaN                         NaN
# 59    408              []             NaN                         NaN
# 60    407              []             NaN                         NaN
# 61    408              []             NaN                         NaN
# 62    408              []             NaN                         NaN
#
#     Single Class Classification  probability
# 0                           NaN          NaN
# 1                           NaN          NaN
# 2                           NaN          NaN
# 3                           NaN          NaN
# 4                           NaN          NaN
# ..                          ...          ...
# 58                          NaN          NaN
# 59                          NaN          NaN
# 60                          NaN          NaN
# 61                          NaN          NaN
# 62                          NaN          NaN
#
# [63 rows x 11 columns]
