# %%
import numpy as np
import pandas as pd
import scipy.stats
import sklearn_crfsuite
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn_crfsuite import metrics

# %% [markdown]
# # Create Evaluation Data Set

# %%
df_test_in = pd.read_csv('../../data_v3/hr_il_tagged.csv')

df_train_in = pd.read_csv('../../data_v3/hr_extended_features.csv')

df_test_in.rename(columns={'real_activity_action': "ActivityAction"}, inplace=True)

df_gt = pd.read_csv('../../data_v3/hr_ground_truth.csv')

# %%
df_test_in = pd.read_csv('../../data_v3/ptp_il_tagged.csv')

df_train_in = pd.read_csv('../../data_v3/ptp_extended_features.csv')

df_test_in.rename(columns={'real_activity_action': "ActivityAction"}, inplace=True)

df_gt = pd.read_csv('../../data_v3/ptp_ground_truth.csv')

# %%
#df_gt = pd.read_csv('../../data_v3/hr_ground_truth.csv')
#df_test["ActivityAction"]=np.select([df_test["frame.number"].isin(df_gt["start"].values),df_test["frame.number"].isin(df_gt["actual_end"].values)], ["Action Start", "Action End"],default="NoAction", )

# %% [markdown]
# 1. Sort Values by Sniff Time
# 2. Validate Start and End Events after Sorting
#     - Group by Instance Number and Business Activity
#     - Check if frame.number is sequential
#     - Check if start activity and end activity are at beginning / end of the sequence
# 3. Features
#     - Event with roles, request_method_call, selective_filter_data, origin_selective_filter_data
#     -

# %% [markdown]
# # 1 Preprocessing
# 1.1 Sort train set by sniff time
# 1.2 Form sequences
# 1.3 Validate sequences for ascending frame.number
# 1.4 Check for correct position of start and end events of each sequence

# %%
df_train_in
# Out:
#        Unnamed: 0.1  Unnamed: 0                      FileName  \
# 0                 0           0  CreatePurchaseRequest_1.pcap
# 1                 1           1  CreatePurchaseRequest_1.pcap
# 2                 2           2  CreatePurchaseRequest_1.pcap
# 3                 3           3  CreatePurchaseRequest_1.pcap
# 4                 4           4  CreatePurchaseRequest_1.pcap
# ...             ...         ...                           ...
# 25951         25951       25822         SubmitPayment_67.pcap
# 25952         25952       25823         SubmitPayment_67.pcap
# 25953         25953       25824         SubmitPayment_67.pcap
# 25954         25954       25825         SubmitPayment_67.pcap
# 25955         25955       25826         SubmitPayment_67.pcap
#
#             BusinessActivity  InstanceNumber                  sniff_time  \
# 0      CreatePurchaseRequest               1  2020-12-21 08:08:44.637118
# 1      CreatePurchaseRequest               1  2020-12-21 08:08:44.688344
# 2      CreatePurchaseRequest               1  2020-12-21 08:08:44.690577
# 3      CreatePurchaseRequest               1  2020-12-21 08:08:44.985813
# 4      CreatePurchaseRequest               1  2020-12-21 08:08:44.994598
# ...                      ...             ...                         ...
# 25951          SubmitPayment              67  2020-12-22 10:19:04.470693
# 25952          SubmitPayment              67  2020-12-22 10:19:04.472504
# 25953          SubmitPayment              67  2020-12-22 10:19:04.473377
# 25954          SubmitPayment              67  2020-12-22 10:19:04.498656
# 25955          SubmitPayment              67  2020-12-22 10:19:04.511095
#
#        frame.number        synthetic_sniff_time    synthetic_sniff_time_str  \
# 0               119  2020-12-22 11:39:44.237118  2020-12-22 11:39:44.237118
# 1               153  2020-12-22 11:48:16.548344  2020-12-22 11:48:16.548344
# 2               161  2020-12-22 11:48:38.880577  2020-12-22 11:48:38.880577
# 3               224  2020-12-22 12:37:51.535813  2020-12-22 12:37:51.535813
# 4               245  2020-12-22 12:39:19.394598  2020-12-22 12:39:19.394598
# ...             ...                         ...                         ...
# 25951          2776  2020-12-23 18:58:19.450693  2020-12-23 18:58:19.450693
# 25952          2778  2020-12-23 18:58:37.562504  2020-12-23 18:58:37.562504
# 25953          2780  2020-12-23 18:58:46.293377  2020-12-23 18:58:46.293377
# 25954          2838  2020-12-23 19:02:59.108656  2020-12-23 19:02:59.108656
# 25955          2857  2020-12-23 19:05:03.511095  2020-12-23 19:05:03.511095
#
#                   session_generalized  ... writeoff_label payment_term_id  \
# 0       192.168.11.2-192.168.11.9 (1)  ...            NaN             NaN
# 1       192.168.11.2-192.168.11.9 (1)  ...            NaN             NaN
# 2       192.168.11.2-192.168.11.9 (2)  ...            NaN             NaN
# 3       192.168.11.1-192.168.11.2 (7)  ...            NaN             NaN
# 4       192.168.11.2-192.168.11.9 (2)  ...            NaN             NaN
# ...                               ...  ...            ...             ...
# 25951   192.168.11.1-192.168.11.2 (6)  ...      Write-Off             NaN
# 25952   192.168.11.1-192.168.11.2 (6)  ...            NaN             NaN
# 25953   192.168.11.1-192.168.11.2 (6)  ...            NaN             NaN
# 25954   192.168.11.1-192.168.11.2 (6)  ...            NaN             NaN
# 25955  192.168.11.2-192.168.11.21 (8)  ...            NaN             NaN
#
#       request_method_call starting_frame_number selective_filter_data  \
# 0                 version                   NaN               version
# 1          server_version                 119.0                   NaN
# 2            authenticate                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                       2                 161.0              IsNumber
# ...                   ...                   ...                   ...
# 25951                 NaN                   NaN                   NaN
# 25952                 NaN                   NaN                   NaN
# 25953                 NaN                   NaN                   NaN
# 25954                 NaN                   NaN                   NaN
# 25955                  77                2719.0              IsNumber
#
#        origin_request_method origin_selective_filter_data IsStartActivity  \
# 0                        NaN                          NaN            True
# 1                    version                      version           False
# 2                        NaN                          NaN           False
# 3                        NaN                          NaN           False
# 4               authenticate                          NaN           False
# ...                      ...                          ...             ...
# 25951                    NaN                          NaN           False
# 25952                    NaN                          NaN           False
# 25953                    NaN                          NaN           False
# 25954                    NaN                          NaN           False
# 25955             execute_kw       account.payment_create           False
#
#       IsEndActivity  ActivityAction
# 0             False  Activity Start
# 1             False        NoAction
# 2             False        NoAction
# 3             False        NoAction
# 4             False        NoAction
# ...             ...             ...
# 25951         False        NoAction
# 25952         False        NoAction
# 25953         False        NoAction
# 25954         False        NoAction
# 25955          True    Activity End
#
# [25956 rows x 259 columns]

# %%
cols = ["event_with_roles", "request_method_call", "selective_filter_data", "origin_selective_filter_data","origin_request_method", "InstanceNumber",
        "BusinessActivity","ActivityAction"]

df_train = df_train_in.sort_values(by=['sniff_time'])[cols]
df_test = df_test_in[cols]

# %%
#df_train["ActivityLabel"] = df_train["ActivityAction"] + " "+df_train["BusinessActivity"]

# %%
# repalce request method call number 
def replace_numeric(value):
    return '' if pd.to_numeric(value, errors='coerce') == value else value

df_train["request_method_call"][pd.notnull(pd.to_numeric(df_train["request_method_call"], errors='coerce'))] = ""

# %%
# form sequences of length 20 
def reshape_sequence(data, seq_length):
    data = data.values
    num_seq = data.shape[0] // seq_length
    return data[:num_seq * seq_length].reshape((num_seq, seq_length, data.shape[1]))


train_seq = reshape_sequence(df_train, 1)
test_seq = reshape_sequence(df_test, 1)

# %%
df_train["selective_filter_data"].value_counts(dropna=False)
# Out:
# selective_filter_data
# NaN                                       21745
# IsNumber                                   1773
# version                                     408
# purchase.order_create                       208
# purchase.order.line_create                  206
# product.product_search_read                 134
# purchase.order_search_read                   93
# purchase.requisition.line_create             67
# sale.order_create                            67
# res.partner_search_read                      67
# sale.order.line_create                       67
# purchase.requisition_write_in_progress       67
# purchase.requisition_write_open              67
# purchase.requisition_write_ongoing           67
# purchase.requisition_create                  66
# purchase.order_write                         63
# sale.order_write_done                        47
# stock.picking_button_validate                47
# account.payment_create                       47
# account.invoice.line_create                  47
# account.invoice_create                       47
# account.journal_search_read                  47
# purchase.requisition_write_done              47
# faultCode                                    47
# stock.move.line_write                        47
# move_line_ids                                47
# stock.move_search_read                       47
# purchase.order_button_confirm                47
# stock.picking_search_read                    47
# picking_ids                                  47
# move_ids_without_package                     47
# account.invoice_action_invoice_open          46
# purchase.requisition_write_cancel            20
# sale.order_write_cancel                      20
# Name: count, dtype: int64

# %%
df_train
# Out:
#                                         event_with_roles request_method_call  \
# 0      End Point (Employee)->Odoo Application: [HttpR...             version
# 1      Odoo Application->End Point (Employee): [HttpR...      server_version
# 2      End Point (Employee)->Odoo Application: [HttpR...        authenticate
# 3      Odoo Application->db Server/Mail Server: [Pgsq...                 NaN
# 4      Odoo Application->End Point (Employee): [HttpR...
# ...                                                  ...                 ...
# 25951  Odoo Application->db Server/Mail Server: [Pgsq...                 NaN
# 25952  Odoo Application->db Server/Mail Server: [Pgsq...                 NaN
# 25953  Odoo Application->db Server/Mail Server: [Pgsq...                 NaN
# 25954  Odoo Application->db Server/Mail Server: [Pgsq...                 NaN
# 25955  Odoo Application->End Point (Finance): [HttpRe...
#
#       selective_filter_data origin_selective_filter_data  \
# 0                   version                          NaN
# 1                       NaN                      version
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                  IsNumber                          NaN
# ...                     ...                          ...
# 25951                   NaN                          NaN
# 25952                   NaN                          NaN
# 25953                   NaN                          NaN
# 25954                   NaN                          NaN
# 25955              IsNumber       account.payment_create
#
#       origin_request_method  InstanceNumber       BusinessActivity  \
# 0                       NaN               1  CreatePurchaseRequest
# 1                   version               1  CreatePurchaseRequest
# 2                       NaN               1  CreatePurchaseRequest
# 3                       NaN               1  CreatePurchaseRequest
# 4              authenticate               1  CreatePurchaseRequest
# ...                     ...             ...                    ...
# 25951                   NaN              67          SubmitPayment
# 25952                   NaN              67          SubmitPayment
# 25953                   NaN              67          SubmitPayment
# 25954                   NaN              67          SubmitPayment
# 25955            execute_kw              67          SubmitPayment
#
#        ActivityAction
# 0      Activity Start
# 1            NoAction
# 2            NoAction
# 3            NoAction
# 4            NoAction
# ...               ...
# 25951        NoAction
# 25952        NoAction
# 25953        NoAction
# 25954        NoAction
# 25955    Activity End
#
# [25956 rows x 8 columns]

# %%
# build feature vectors

def seq2features(seq, bw, fw, feature_list):
    return [event2features(seq, i, bw, fw, feature_list) for i in range(len(seq))]



def event2features(seq, i, bw, fw, feature_list):
    # event features (position i in sequence)
    features = {
        feature_list[j]: seq[i, j] for j in range(len(feature_list))
    }

    ## backward features 1...bw

    for k in range(1,bw+1): 
        index = i - k
        if index >= 0: 
            features.update({
                f"-{k}:{feature_list[j]}" : seq[index,j] for j in range(len(feature_list))
            })

    ## forward features 1...fw

    for k in range(1, fw+1): 
        index = i + k
        if index < len(seq): 
            features.update({
                f"+{k}:{feature_list[j]}" : seq[index, j] for j in range(len(feature_list))
            })

    ## remove all empty String features        

    # features = {key: value for key, value in features.items() if value != ''}
    features.update({"bias": 1.0})
    return features


feature_list = [ "event_with_roles","request_method_call", "selective_file_data","origin_request_method", "origin_file_data"]
fw = 0
bw = 0

train_features = [seq2features(s, bw, fw, feature_list) for s in train_seq]
train_labels = train_seq[:, :, -1]
train_labels_activity = train_seq[:,:,-1]

test_features = [seq2features(s, bw, fw, feature_list) for s in test_seq]
test_labels = test_seq[:, :, -1]

# %%
train_features
# Out:
# [[{'event_with_roles': 'End Point (Employee)->Odoo Application: [HttpRequest:POST /xmlrpc/2/common HTTP/1.1\\r\\n]',
#    'request_method_call': 'version',
#    'selective_file_data': 'version',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Employee): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': 'server_version',
#    'selective_file_data': nan,
#    'origin_request_method': 'version',
#    'origin_file_data': 'version',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Employee)->Odoo Application: [HttpRequest:POST /xmlrpc/2/common HTTP/1.1\\r\\n]',
#    'request_method_call': 'authenticate',
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['res_users_log']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Employee): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': nan,
#    'origin_file_data': 'authenticate',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Employee)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'product.product_search_read',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Employee): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': 'id',
#    'selective_file_data': nan,
#    'origin_request_method': 'product.product_search_read',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Employee)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'sale.order_create',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['sale_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_followers']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_followers_mail_message_subtype_rel']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_tracking_value']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_tracking_value']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Employee): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'sale.order_create',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Employee)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'sale.order.line_create',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['sale_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Employee): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'sale.order.line_create',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/common HTTP/1.1\\r\\n]',
#    'request_method_call': 'version',
#    'selective_file_data': 'version',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': 'server_version',
#    'selective_file_data': nan,
#    'origin_request_method': 'version',
#    'origin_file_data': 'version',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/common HTTP/1.1\\r\\n]',
#    'request_method_call': 'authenticate',
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['res_users_log']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': nan,
#    'origin_file_data': 'authenticate',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'purchase.requisition_create',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['purchase_requisition']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_followers']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_followers_mail_message_subtype_rel']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'purchase.requisition_create',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'purchase.requisition.line_create',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['purchase_requisition_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_requisition_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'purchase.requisition.line_create',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'purchase.requisition_write_ongoing',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_requisition']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'purchase.requisition_write_ongoing',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['fetchmail_server']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/common HTTP/1.1\\r\\n]',
#    'request_method_call': 'version',
#    'selective_file_data': 'version',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': 'server_version',
#    'selective_file_data': nan,
#    'origin_request_method': 'version',
#    'origin_file_data': 'version',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/common HTTP/1.1\\r\\n]',
#    'request_method_call': 'authenticate',
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['res_users_log']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': nan,
#    'origin_file_data': 'authenticate',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'product.product_search_read',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': 'id',
#    'selective_file_data': nan,
#    'origin_request_method': 'product.product_search_read',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'res.partner_search_read',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': 'id',
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'purchase.order_create',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_followers']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_followers_mail_message_subtype_rel']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_tracking_value']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_tracking_value']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_compose_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_mail']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_mail_res_partner_rel']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['message_attachment_rel']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_mail']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'purchase.order_create',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'purchase.order.line_create',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'purchase.order.line_create',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'purchase.order_create',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_followers']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_followers_mail_message_subtype_rel']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_tracking_value']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_tracking_value']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_compose_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_mail']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_mail_res_partner_rel']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['message_attachment_rel']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_mail']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'purchase.order_create',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'purchase.order.line_create',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'purchase.order.line_create',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'purchase.order_create',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_followers']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_followers_mail_message_subtype_rel']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_tracking_value']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_tracking_value']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_compose_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_mail']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_mail_res_partner_rel']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
# ...
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_tracking_value']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_tracking_value']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_compose_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_mail']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_mail_res_partner_rel']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['ir_attachment']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['message_attachment_rel']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_mail']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'purchase.order_create',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'purchase.order.line_create',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_order_line']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'purchase.order.line_create',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'purchase.requisition_write_in_progress',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_requisition']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'purchase.requisition_write_in_progress',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_mail']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->db Server/Mail Server: [SmtpReassembledMessage]',
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_mail']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_mail']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['mail_mail']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['fetchmail_server']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/common HTTP/1.1\\r\\n]',
#    'request_method_call': 'version',
#    'selective_file_data': 'version',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': 'server_version',
#    'selective_file_data': nan,
#    'origin_request_method': 'version',
#    'origin_file_data': 'version',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/common HTTP/1.1\\r\\n]',
#    'request_method_call': 'authenticate',
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['res_users_log']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': nan,
#    'origin_file_data': 'authenticate',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/object HTTP/1.1\\r\\n]',
#    'request_method_call': 'execute_kw',
#    'selective_file_data': 'purchase.requisition_write_open',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:UPDATE:['purchase_requisition']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['mail_message']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': '',
#    'selective_file_data': 'IsNumber',
#    'origin_request_method': 'purchase.requisition_write_open',
#    'origin_file_data': 'execute_kw',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/common HTTP/1.1\\r\\n]',
#    'request_method_call': 'version',
#    'selective_file_data': 'version',
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': 'Odoo Application->End Point (Procurement): [HttpResponse:HTTP/1.0 200 OK\\r\\n]',
#    'request_method_call': 'server_version',
#    'selective_file_data': nan,
#    'origin_request_method': 'version',
#    'origin_file_data': 'version',
#    'bias': 1.0}],
#  [{'event_with_roles': 'End Point (Procurement)->Odoo Application: [HttpRequest:POST /xmlrpc/2/common HTTP/1.1\\r\\n]',
#    'request_method_call': 'authenticate',
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  [{'event_with_roles': "Odoo Application->db Server/Mail Server: [PgsqlRequest:Simple query:INSERT:['res_users_log']]",
#    'request_method_call': nan,
#    'selective_file_data': nan,
#    'origin_request_method': nan,
#    'origin_file_data': nan,
#    'bias': 1.0}],
#  ...]

# %%
X_train, X_test, y_train, y_test = train_test_split(train_features, train_labels_activity, test_size=0.3, random_state=42)

# %% [markdown]
# ### Train CRF Model

# %%
# %%time
crf = sklearn_crfsuite.CRF(
    max_iterations=200,
    c1=0.1,
    c2=0.01,
    all_possible_transitions=True
    #all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# CPU times: user 461 ms, sys: 8.38 ms, total: 469 ms
# Wall time: 481 ms
# CRF(all_possible_transitions=True, c1=0.1, c2=0.01, max_iterations=200)

# %%
def flatten(xss):
    return [x for xs in xss for x in xs]


def evaluate(model, x, y_true):
    y_pred = model.predict(x)
    print(metrics.flat_f1_score(y_true, y_pred, average='macro', labels=model.classes_))
    print(metrics.flat_classification_report(y_true, y_pred, model.classes_))
    print(multilabel_confusion_matrix(flatten(y_true), flatten(y_pred)))


evaluate(crf, X_test, y_test)
# Out:
# 0.9207747787496299
#                 precision    recall  f1-score   support
#
#       NoAction       0.99      1.00      1.00      7534
#   Activity End       0.94      0.64      0.77       132
# Activity Start       1.00      1.00      1.00       121
#
#       accuracy                           0.99      7787
#      macro avg       0.98      0.88      0.92      7787
#   weighted avg       0.99      0.99      0.99      7787
#
# [[[7650    5]
#   [  47   85]]
#
#  [[7666    0]
#   [   0  121]]
#
#  [[ 206   47]
#   [   5 7529]]]

# %%
evaluate(crf, test_features, test_labels)
# Out:
# 0.8487744079767344
#                 precision    recall  f1-score   support
#
#       NoAction       0.99      1.00      0.99      3591
#   Activity End       1.00      0.38      0.55        63
# Activity Start       1.00      1.00      1.00        63
#
#       accuracy                           0.99      3717
#      macro avg       1.00      0.79      0.85      3717
#   weighted avg       0.99      0.99      0.99      3717
#
# [[[3654    0]
#   [  39   24]]
#
#  [[3654    0]
#   [   0   63]]
#
#  [[  87   39]
#   [   0 3591]]]

# %%
df_test
# Out:
#                                        event_with_roles request_method_call  \
# 0     End Point (Employee)->Odoo Application: [HttpR...             version
# 1     Odoo Application->End Point (Employee): [HttpR...      server_version
# 2     End Point (Employee)->Odoo Application: [HttpR...        authenticate
# 3     Odoo Application->db Server/Mail Server: [Pgsq...                 NaN
# 4     Odoo Application->End Point (Employee): [HttpR...                   2
# ...                                                 ...                 ...
# 3712  Odoo Application->db Server/Mail Server: [Pgsq...                 NaN
# 3713  Odoo Application->db Server/Mail Server: [Pgsq...                 NaN
# 3714  Odoo Application->db Server/Mail Server: [Pgsq...                 NaN
# 3715  Odoo Application->db Server/Mail Server: [Pgsq...                 NaN
# 3716  Odoo Application->End Point (Finance): [HttpRe...                 246
#
#      selective_filter_data origin_selective_filter_data origin_request_method  \
# 0                  version                          NaN                   NaN
# 1                      NaN                      version               version
# 2                      NaN                          NaN                   NaN
# 3                      NaN                          NaN                   NaN
# 4                 IsNumber                          NaN          authenticate
# ...                    ...                          ...                   ...
# 3712                   NaN                          NaN                   NaN
# 3713                   NaN                          NaN                   NaN
# 3714                   NaN                          NaN                   NaN
# 3715                   NaN                          NaN                   NaN
# 3716              IsNumber       account.payment_create            execute_kw
#
#       InstanceNumber                   BusinessActivity  ActivityAction
# 0               2022  order_to_cash_interleaved_10cases  Activity Start
# 1               2022  order_to_cash_interleaved_10cases        NoAction
# 2               2022  order_to_cash_interleaved_10cases        NoAction
# 3               2022  order_to_cash_interleaved_10cases        NoAction
# 4               2022  order_to_cash_interleaved_10cases        NoAction
# ...              ...                                ...             ...
# 3712            2022  order_to_cash_interleaved_10cases        NoAction
# 3713            2022  order_to_cash_interleaved_10cases        NoAction
# 3714            2022  order_to_cash_interleaved_10cases        NoAction
# 3715            2022  order_to_cash_interleaved_10cases        NoAction
# 3716            2022  order_to_cash_interleaved_10cases    Activity End
#
# [3717 rows x 8 columns]

# %%
import scipy
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer

# define fixed parameters and parameters to search
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    max_iterations=100, 
    all_possible_transitions=True
)
params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05),
}

# use the same metric for evaluation
f1_scorer = make_scorer(metrics.flat_f1_score, 
                        average='macro', labels=np.unique(test_labels))

# search
rs = RandomizedSearchCV(crf, params_space, 
                        cv=3, 
                        verbose=1, 
                        n_jobs=-1, 
                        n_iter=50, 
                        scoring=f1_scorer)
rs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# KeyboardInterrupt

# %%
crf = rs.best_estimator_
evaluate(crf, X_test, y_test)
evaluate(crf, test_features, test_labels)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 crf = rs.best_estimator_
#       2 evaluate(crf, X_test, y_test)
#       3 evaluate(crf, test_features, test_labels)
#
# AttributeError: 'RandomizedSearchCV' object has no attribute 'best_estimator_'

# %%
evaluate(crf, test_features, test_labels)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 evaluate(crf, test_features, test_labels)
#
# Cell In[16], line 6, in evaluate(model, x, y_true)
#       5 def evaluate(model, x, y_true):
# ----> 6     y_pred = model.predict(x)
#       7     print(metrics.flat_f1_score(y_true, y_pred, average='macro', labels=model.classes_))
#       8     print(metrics.flat_classification_report(y_true, y_pred, model.classes_))
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/sklearn_crfsuite/estimator.py:352, in CRF.predict(self, X)
#     337 def predict(self, X):
#     338     """
#     339     Make a prediction.
#     340
#    (...)
#     350
#     351     """
# --> 352     return list(map(self.predict_single, X))
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/sklearn_crfsuite/estimator.py:369, in CRF.predict_single(self, xseq)
#     354 def predict_single(self, xseq):
#     355     """
#     356     Make a prediction.
#     357
#    (...)
#     367
#     368     """
# --> 369     return self.tagger_.tag(xseq)
#
# AttributeError: 'NoneType' object has no attribute 'tag'

# %%
from collections import Counter


def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))


print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common())
# Out:
# Top likely transitions:

# %%
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))


print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(30))

print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-30:])
# Out:
# Top positive:
#
# Top negative:

# %% [markdown]
# # Categorical NB

# %%
train_array = np.array([list(item[0].values()) for item in train_features])[:,:-1]
test_array = np.array([list(item[0].values()) for item in test_features])[:,:-1]

train_array[train_array == "nan"] = ""
test_array[test_array == "nan"] = ""

# replace numeric values in method call
train_array[:,1] = np.where(np.logical_not(np.char.isdigit(train_array[:,1])), train_array[:,1], "")
test_array[:,1] = np.where(np.logical_not(np.char.isdigit(test_array[:,1])), test_array[:,1], "")

# %%
from sklearn.preprocessing import LabelEncoder

# Label Encode Data
label_encoders = [LabelEncoder() for _ in range(train_array.shape[1]-1)]

for i, encoder in enumerate(label_encoders):
    train_array[:,i] = encoder.fit_transform(train_array[:,i])
    test_array[:,i] = encoder.transform(test_array[:,i])
    
# Encode origin selective filter data same as selective filter data
train_array[:,-1] = label_encoders[-1].transform(train_array[:,-1])
test_array[:,-1] = label_encoders[-1].transform(test_array[:,-1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/sklearn/utils/_encode.py:225, in _encode(values, uniques, check_unknown)
#     224 try:
# --> 225     return _map_to_integer(values, uniques)
#     226 except KeyError as e:
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/sklearn/utils/_encode.py:165, in _map_to_integer(values, uniques)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/sklearn/utils/_encode.py:165, in <listcomp>(.0)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/sklearn/utils/_encode.py:159, in _nandict.__missing__(self, key)
#     158     return self.nan_value
# --> 159 raise KeyError(key)
#
# KeyError: 'product.product_search_read_name'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 8
#       6 for i, encoder in enumerate(label_encoders):
#       7     train_array[:,i] = encoder.fit_transform(train_array[:,i])
# ----> 8     test_array[:,i] = encoder.transform(test_array[:,i])
#      10 # Encode origin selective filter data same as selective filter data
#      11 train_array[:,-1] = label_encoders[-1].transform(train_array[:,-1])
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:137, in LabelEncoder.transform(self, y)
#     134 if _num_samples(y) == 0:
#     135     return np.array([])
# --> 137 return _encode(y, uniques=self.classes_)
#
# File ~/git/master_thesis/nw_event_abstraction/venv/lib/python3.9/site-packages/sklearn/utils/_encode.py:227, in _encode(values, uniques, check_unknown)
#     225         return _map_to_integer(values, uniques)
#     226     except KeyError as e:
# --> 227         raise ValueError(f"y contains previously unseen labels: {str(e)}")
#     228 else:
#     229     if check_unknown:
#
# ValueError: y contains previously unseen labels: 'product.product_search_read_name'

# %%
train_labels = train_labels.ravel()
test_labels = test_labels.ravel()

# %%
train_labels
# Out:
# array(['Activity Start', 'NoAction', 'NoAction', ..., 'NoAction',
#        'NoAction', 'Activity End'], dtype=object)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_array, train_labels, test_size=0.3, random_state=42)

# %%
from sklearn.naive_bayes import CategoricalNB

clf = CategoricalNB()

# %%
clf.fit(X_train, y_train)

# %%
from sklearn.model_selection import RandomizedSearchCV
import scipy
from sklearn.metrics import make_scorer, f1_score

clf = CategoricalNB()
params_space = {
    "alpha": scipy.stats.expon(scale=0.05)   
}

f1_scorer = make_scorer(f1_score, average="macro")

rs = RandomizedSearchCV(clf, params_space, cv = 3, verbose =1,n_jobs=-1, n_iter=300, scoring = f1_scorer)

rs.fit(X_train, y_train)

# %%
# crf = rs.best_estimator_
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
clf = rs.best_estimator_

# %%
from sklearn.metrics import classification_report

def evaluate(model, X, y): 
    pred = model.predict(X)
    print(classification_report(y, pred))
    
print("------  Test Data  ------")
evaluate(clf, X_test, y_test)
print("------ INTERLEAVED ------")
evaluate(clf, test_array, test_labels)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(random_state=42)

# %%
clf.fit(X_train, y_train)

# %%
evaluate(clf, X_test, y_test)

# %%
evaluate(clf, test_array, test_labels)

# %%
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import scipy
from sklearn.metrics import make_scorer, f1_score

clf = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [4, 5, 6, 7, 8],
    'criterion': ['gini', 'entropy']
}

f1_scorer = make_scorer(f1_score, average="macro")

rs = GridSearchCV(clf, param_grid, cv = 3, verbose =1,n_jobs=-1, scoring = f1_scorer)

rs.fit(X_train, y_train)

# %%
# crf = rs.best_estimator_
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
clf = rs.best_estimator_

# %%
print("------  Test Data  ------")
evaluate(clf, X_test, y_test)
print("------ INTERLEAVED ------")
evaluate(clf, test_array, test_labels)
